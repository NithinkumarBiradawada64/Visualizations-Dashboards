# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import create_engin

# %%
df=pd.read_csv("Hospital_Inpatient_Discharges.csv")
df.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Bronx                     7000006.0
# 1         New York City           Bronx                     7000006.0
# 2         New York City           Bronx                     7000006.0
# 3         New York City           Bronx                     7000006.0
# 4         New York City           Bronx                     7000006.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 1                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 2                 1168.0       Montefiore Medical Center-Wakefield Hospital
# 3                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 4                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
#
#      Age Group Zip Code - 3 digits Gender                    Race  \
# ...

# %%
df.shape
# Out:
# (2101588, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2101588 entries, 0 to 2101587
# Data columns (total 33 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Hospital Service Area                object
#  1   Hospital County                      object
#  2   Operating Certificate Number         float64
#  3   Permanent Facility Id                float64
#  4   Facility Name                        object
#  5   Age Group                            object
#  6   Zip Code - 3 digits                  object
#  7   Gender                               object
#  8   Race                                 object
#  9   Ethnicity                            object
#  10  Length of Stay                       object
#  11  Type of Admission                    object
#  12  Patient Disposition                  object
#  13  Discharge Year                       int64
#  14  CCSR Diagnosis Code                  object
# ...

# %%
df["Length of Stay"]=pd.to_numeric(df["Length of Stay"],errors='coerce')
df["Birth Weight"]=pd.to_numeric(df["Birth Weight"],errors='coerce')
df["Total Charges"]=pd.to_numeric(df["Total Charges"],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2101588 entries, 0 to 2101587
# Data columns (total 33 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Hospital Service Area                object
#  1   Hospital County                      object
#  2   Operating Certificate Number         float64
#  3   Permanent Facility Id                float64
#  4   Facility Name                        object
#  5   Age Group                            object
#  6   Zip Code - 3 digits                  object
#  7   Gender                               object
#  8   Race                                 object
#  9   Ethnicity                            object
#  10  Length of Stay                       float64
#  11  Type of Admission                    object
#  12  Patient Disposition                  object
#  13  Discharge Year                       int64
#  14  CCSR Diagnosis Code                  object
# ...

# %%
df.isnull().sum()
# Out:
# Hospital Service Area                    10642
# Hospital County                          10642
# Operating Certificate Number             12091
# Permanent Facility Id                    10642
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                      45062
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                            1561
# Type of Admission                            0
# Patient Disposition                          0
# Discharge Year                               0
# CCSR Diagnosis Code                       1634
# CCSR Diagnosis Description                1634
# CCSR Procedure Code                     576021
# CCSR Procedure Description              576021
# APR DRG Code                                 0
# APR DRG Description                          0
# ...

# %%
df["Hospital Service Area"].fillna("Unknow",inplace=True)
df["Hospital County"].fillna("Unknow",inplace=True)
df["Operating Certificate Number"].fillna(00000,inplace=True)
df["Permanent Facility Id"].fillna(0000,inplace=True)
df["Zip Code - 3 digits"].fillna("Unknow",inplace=True)
df["CCSR Diagnosis Code"].fillna("Unknow",inplace=True)
df["CCSR Diagnosis Description"].fillna("Unknow",inplace=True)
df["CCSR Procedure Code"].fillna("Unknow",inplace=True)
df["CCSR Procedure Description"].fillna("Unknow",inplace=True)
df["APR Severity of Illness Description"].fillna("Unknow",inplace=True)
df["APR Risk of Mortality"].fillna("Unknow", inplace=True)
df["Payment Typology 2"].fillna("Unknow", inplace=True)
df["Payment Typology 3"].fillna("Unknow", inplace=True)
df["Length of Stay"].fillna(0, inplace=True)
df["Birth Weight"].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Hospital Service Area                        0
# Hospital County                              0
# Operating Certificate Number                 0
# Permanent Facility Id                        0
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                          0
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                          0
# Discharge Year                               0
# CCSR Diagnosis Code                          0
# CCSR Diagnosis Description                   0
# CCSR Procedure Code                          0
# CCSR Procedure Description                   0
# APR DRG Code                                 0
# APR DRG Description                          0
# ...

# %%
db_user = 'postgres'
db_password = 'Nithin'
db_host = 'localhost'       
db_port = '5432'            
db_name = 'hospital'
connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
engine = create_engine(connection_string)

# %%
df.to_sql('hospital_discharges', engine, index=False, if_exists='replace')
# Out:
# 808
